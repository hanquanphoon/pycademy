# %%
# !pip install pandas
# !pip install seaborn
# !pip install sklearn

# %%
import pandas as pd
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("iris-mv.csv")
df
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         NaN          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 130          6.8         3.2          5.9         2.3  Iris-virginica
# 131          6.7         3.3          5.7         2.5  Iris-virginica
# 132          6.3         2.5          5.0         1.9  Iris-virginica
# 133          6.5         3.0          5.2         2.0  Iris-virginica
# 134          5.9         3.0          5.1         1.8  Iris-virginica
#
# [135 rows x 5 columns]

# %%
df.head()
# Out:
#    SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         NaN          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SepalLength  121 non-null    float64
#  1   SepalWidth   124 non-null    float64
#  2   PetalLength  116 non-null    float64
#  3   PetalWidth   125 non-null    float64
#  4   Species      135 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.4+ KB

# %%
df['SepalLength']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4        5
#       ...
# 130    6.8
# 131    6.7
# 132    6.3
# 133    6.5
# 134    5.9
# Name: sepalLength, Length: 135, dtype: object

# %%
df.SepalLength
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4        5
#       ...
# 130    6.8
# 131    6.7
# 132    6.3
# 133    6.5
# 134    5.9
# Name: sepalLength, Length: 135, dtype: object

# %%
df.iloc[100]
# Out:
# SepalLength               6.4
# SepalWidth                2.7
# PetalLength               NaN
# PetalWidth                1.9
# Species        Iris-virginica
# Name: 100, dtype: object

# %%
df.iloc[:,1:3]
# Out:
#      SepalWidth  PetalLength
# 0           3.5          1.4
# 1           3.0          1.4
# 2           NaN          1.3
# 3           3.1          1.5
# 4           3.6          1.4
# ..          ...          ...
# 130         3.2          5.9
# 131         3.3          5.7
# 132         2.5          5.0
# 133         3.0          5.2
# 134         3.0          5.1
#
# [135 rows x 2 columns]

# %%
df.loc[:,'SepalLength']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 130    6.8
# 131    6.7
# 132    6.3
# 133    6.5
# 134    5.9
# Name: SepalLength, Length: 135, dtype: float64

# %%
df.loc[df['Species']=='Iris-setosa']
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth      Species
# 0           5.1         3.5          1.4         0.2  Iris-setosa
# 1           4.9         3.0          1.4         0.2  Iris-setosa
# 2           4.7         3.0          1.3         0.2  Iris-setosa
# 3           4.6         3.1          1.5         0.2  Iris-setosa
# 4           5.0         3.6          1.4         0.2  Iris-setosa
# 5           5.4         3.9          1.7         0.4  Iris-setosa
# 6           4.6         3.4          1.4         0.3  Iris-setosa
# 7           5.0         3.4          1.5         0.2  Iris-setosa
# 8           4.4         2.9          1.5         0.2  Iris-setosa
# 9           4.9         2.9          1.5         0.1  Iris-setosa
# 10          4.9         3.7          1.5         0.2  Iris-setosa
# 11          4.8         3.4          1.6         0.2  Iris-setosa
# 12          4.8         3.0          1.4         0.1  Iris-setosa
# ...

# %%
df.drop([1,3,15])
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 2            4.7         NaN          1.3         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# 5            5.4         3.9          1.7         0.4     Iris-setosa
# 6            4.6         3.4          1.4         0.3     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 130          6.8         3.2          5.9         2.3  Iris-virginica
# 131          6.7         3.3          5.7         2.5  Iris-virginica
# 132          6.3         2.5          5.0         1.9  Iris-virginica
# 133          6.5         3.0          5.2         2.0  Iris-virginica
# 134          5.9         3.0          5.1         1.8  Iris-virginica
#
# [132 rows x 5 columns]

# %%
df.drop(['SepalLength'],axis=1)
# Out:
#      SepalWidth  PetalLength  PetalWidth         Species
# 0           3.5          1.4         0.2     Iris-setosa
# 1           3.0          1.4         0.2     Iris-setosa
# 2           NaN          1.3         0.2     Iris-setosa
# 3           3.1          1.5         0.2     Iris-setosa
# 4           3.6          1.4         0.2     Iris-setosa
# ..          ...          ...         ...             ...
# 130         3.2          5.9         2.3  Iris-virginica
# 131         3.3          5.7         2.5  Iris-virginica
# 132         2.5          5.0         1.9  Iris-virginica
# 133         3.0          5.2         2.0  Iris-virginica
# 134         3.0          5.1         1.8  Iris-virginica
#
# [135 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# SepalLength    14
# SepalWidth     11
# PetalLength    19
# PetalWidth     10
# Species         0
# dtype: int64

# %%
df.dropna(axis=0)
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth         Species
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# 5            5.4         3.9          1.7         0.4     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 130          6.8         3.2          5.9         2.3  Iris-virginica
# 131          6.7         3.3          5.7         2.5  Iris-virginica
# 132          6.3         2.5          5.0         1.9  Iris-virginica
# 133          6.5         3.0          5.2         2.0  Iris-virginica
# 134          5.9         3.0          5.1         1.8  Iris-virginica
#
# [86 rows x 5 columns]

# %%
df = df.fillna(method='ffill')
df.isnull().sum()
# Out:
# SepalLength    0
# SepalWidth     0
# PetalLength    0
# PetalWidth     0
# Species        0
# dtype: int64

# %%
sns.pairplot(df,hue="Species")
